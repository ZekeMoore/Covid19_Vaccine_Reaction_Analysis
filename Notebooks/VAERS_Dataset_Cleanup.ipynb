# %% [raw]
# VAERSData Cleanup

# %%
# Add the Pandas dependency.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Files to load
data_csv = "2021VAERSData.csv"
vax_csv = "2021VAERSVAX.csv"
symptoms_csv = "2021VAERSSYMPTOMS.csv"

# %%
# VAERSData Dataframe
vaers_data = pd.read_csv(data_csv, index_col=None, header=0, encoding='latin1', low_memory=False)
vaers_data
# Out:
#         VAERS_ID    RECVDATE STATE  AGE_YRS  CAGE_YR  CAGE_MO SEX RPT_DATE  \
# 0         916600    1/1/2021    TX     33.0     33.0      NaN   F      NaN
# 1         916601    1/1/2021    CA     73.0     73.0      NaN   F      NaN
# 2         916602    1/1/2021    WA     23.0     23.0      NaN   F      NaN
# 3         916603    1/1/2021    WA     58.0     58.0      NaN   F      NaN
# 4         916604    1/1/2021    TX     47.0     47.0      NaN   F      NaN
# ...          ...         ...   ...      ...      ...      ...  ..      ...
# 721465   1939059  12/10/2021    IL     40.0     40.0      NaN   F      NaN
# 721466   1939060  12/10/2021    ME     48.0     48.0      NaN   F      NaN
# 721467   1939061  12/10/2021    IN     46.0     46.0      NaN   M      NaN
# 721468   1939062  12/10/2021    ME     75.0     75.0      NaN   M      NaN
# 721469   1939063  12/10/2021    CA     39.0     39.0      NaN   F      NaN
#
#                                              SYMPTOM_TEXT DIED  ...  \
# 0       Right side of epiglottis swelled up and hinder...  NaN  ...
# 1       Approximately 30 min post vaccination administ...  NaN  ...
# 2       About 15 minutes after receiving the vaccine, ...  NaN  ...
# 3       extreme fatigue, dizziness,. could not lift my...  NaN  ...
# 4       Injection site swelling, redness, warm to the ...  NaN  ...
# ...                                                   ...  ...  ...
# 721465  My S/S occured <24hrs, right breast doubled in...  NaN  ...
# 721466                   Error: Incorrect Reconstitution-  NaN  ...
# 721467              Swollen lymph node under same armpit.  NaN  ...
# 721468                   Error: Incorrect Reconstitution-  NaN  ...
# 721469  Facial and neck swelling for 45 min after firs...  NaN  ...
#
#                                                   CUR_ILL  \
# 0                                                    None
# 1       Patient residing at nursing facility. See pati...
# 2                                                    None
# 3                                        kidney infection
# 4                                                      Na
# ...                                                   ...
# 721465                                         none noted
# 721466                                                NaN
# 721467                                                NaN
# 721468                                                NaN
# 721469                                                 No
#
#                                                   HISTORY  \
# 0                                                    None
# 1       Patient residing at nursing facility. See pati...
# 2                                                    None
# 3       diverticulitis, mitral valve prolapse, osteoar...
# 4                                                     NaN
# ...                                                   ...
# 721465                                Anxiety, depression
# 721466                                                NaN
# 721467                                                NaN
# 721468                                                NaN
# 721469                                                 No
#
#                                                 PRIOR_VAX SPLTTYPE  FORM_VERS  \
# 0                                                     NaN      NaN          2
# 1                                                     NaN      NaN          2
# 2                                                     NaN      NaN          2
# 3       got measles from measel shot, mums from mumps ...      NaN          2
# 4                                                     NaN      NaN          2
# ...                                                   ...      ...        ...
# 721465                                                NaN      NaN          2
# 721466                                                NaN      NaN          2
# 721467                                                NaN      NaN          2
# 721468                                                NaN      NaN          2
# 721469                                                NaN      NaN          2
#
#        TODAYS_DATE BIRTH_DEFECT OFC_VISIT ER_ED_VISIT  \
# 0         1/1/2021          NaN         Y         NaN
# 1         1/1/2021          NaN         Y         NaN
# 2         1/1/2021          NaN       NaN           Y
# 3         1/1/2021          NaN       NaN         NaN
# 4         1/1/2021          NaN       NaN         NaN
# ...            ...          ...       ...         ...
# 721465  12/10/2021          NaN         Y           Y
# 721466  12/10/2021          NaN       NaN         NaN
# 721467  12/10/2021          NaN       NaN         NaN
# 721468  12/10/2021          NaN       NaN         NaN
# 721469  12/10/2021          NaN       NaN         NaN
#
#                                                 ALLERGIES
# 0                                       Pcn and bee venom
# 1                                                 "Dairy"
# 2                                               Shellfish
# 3       Diclofenac, novacaine, lidocaine, pickles, tom...
# 4                                                      Na
# ...                                                   ...
# 721465                                               none
# 721466                                                NaN
# 721467                                                NaN
# 721468                                                NaN
# 721469                                          Shellfish
#
# [721470 rows x 35 columns]

# %%
# Check vaers_data_df columns
vaers_data.columns
# Out:
# Index(['VAERS_ID', 'RECVDATE', 'STATE', 'AGE_YRS', 'CAGE_YR', 'CAGE_MO', 'SEX',
#        'RPT_DATE', 'SYMPTOM_TEXT', 'DIED', 'DATEDIED', 'L_THREAT', 'ER_VISIT',
#        'HOSPITAL', 'HOSPDAYS', 'X_STAY', 'DISABLE', 'RECOVD', 'VAX_DATE',
#        'ONSET_DATE', 'NUMDAYS', 'LAB_DATA', 'V_ADMINBY', 'V_FUNDBY',
#        'OTHER_MEDS', 'CUR_ILL', 'HISTORY', 'PRIOR_VAX', 'SPLTTYPE',
#        'FORM_VERS', 'TODAYS_DATE', 'BIRTH_DEFECT', 'OFC_VISIT', 'ER_ED_VISIT',
#        'ALLERGIES'],
#       dtype='object')

# %%
# Drop  Columns 
clean_vaers_data_df = vaers_data.drop(columns =['CAGE_YR', 'CAGE_MO', 'RPT_DATE', 'ONSET_DATE','NUMDAYS', 'LAB_DATA', 'SYMPTOM_TEXT', 
                                                   'V_ADMINBY', 'DATEDIED', 'V_FUNDBY', 'OTHER_MEDS', 'CUR_ILL', 'PRIOR_VAX','VAX_DATE',
                                                   'SPLTTYPE', 'FORM_VERS', 'TODAYS_DATE', 'OFC_VISIT', 'HISTORY', 'ER_ED_VISIT', 'ALLERGIES',
                                                   'RECVDATE','STATE','HOSPDAYS','X_STAY','RECOVD'])
clean_vaers_data_df
# Out:
#         VAERS_ID  AGE_YRS SEX DIED L_THREAT ER_VISIT HOSPITAL DISABLE  \
# 0         916600     33.0   F  NaN      NaN      NaN      NaN     NaN
# 1         916601     73.0   F  NaN      NaN      NaN      NaN     NaN
# 2         916602     23.0   F  NaN      NaN      NaN      NaN     NaN
# 3         916603     58.0   F  NaN      NaN      NaN      NaN     NaN
# 4         916604     47.0   F  NaN      NaN      NaN      NaN     NaN
# ...          ...      ...  ..  ...      ...      ...      ...     ...
# 721465   1939059     40.0   F  NaN      NaN      NaN      NaN     NaN
# 721466   1939060     48.0   F  NaN      NaN      NaN      NaN     NaN
# 721467   1939061     46.0   M  NaN      NaN      NaN      NaN     NaN
# 721468   1939062     75.0   M  NaN      NaN      NaN      NaN     NaN
# 721469   1939063     39.0   F  NaN      NaN      NaN      NaN     NaN
#
#        BIRTH_DEFECT
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 721465          NaN
# 721466          NaN
# 721467          NaN
# 721468          NaN
# 721469          NaN
#
# [721470 rows x 9 columns]

# %%
# Verify Columns
clean_vaers_data_df.columns
# Out:
# Index(['VAERS_ID', 'AGE_YRS', 'SEX', 'DIED', 'L_THREAT', 'ER_VISIT',
#        'HOSPITAL', 'DISABLE', 'BIRTH_DEFECT'],
#       dtype='object')

# %%
# Checking for Null Values
clean_vaers_data_df.isnull().sum()
# Out:
# VAERS_ID             0
# AGE_YRS          79085
# SEX                  0
# DIED            711894
# L_THREAT        710529
# ER_VISIT        721398
# HOSPITAL        676228
# DISABLE         709687
# BIRTH_DEFECT    721036
# dtype: int64

# %%
# Change NaN to N on L_THREAT
clean_vaers_data_df.L_THREAT.fillna(value = "N", inplace=True)

# %%
# Change NaN to N on DIED
clean_vaers_data_df.DIED.fillna(value = "N", inplace=True)

# %%
# Change NaN to N on ER_VISIT
clean_vaers_data_df.ER_VISIT.fillna(value = "N", inplace=True)

# %%
# Change NaN to N on HOSPITAL
clean_vaers_data_df.HOSPITAL.fillna(value = "N", inplace=True)

# %%
# Change NaN to N on DISABLE
clean_vaers_data_df.DISABLE.fillna(value = "N", inplace=True)

# %%
# Change NaN to N on BIRTH_DEFECT
clean_vaers_data_df.BIRTH_DEFECT.fillna(value = "N", inplace=True)

# %%
# Change NaN to 0 on AGE_YRS
clean_vaers_data_df['AGE_YRS'].fillna(clean_vaers_data_df.groupby('SEX')['AGE_YRS'].transform("median"), inplace=True)
clean_vaers_data_df['AGE_YRS'].head()
# Out:
# 0    33.0
# 1    73.0
# 2    23.0
# 3    58.0
# 4    47.0
# Name: AGE_YRS, dtype: float64

# %%
# Establish the spending bins and group names.
bins = [0, 19.0, 41.0, 60.0, 110.0]
labels = ["0-18", "19-40", "41-59", "60+"]

# %%
# Verifying data types in dataframe
clean_vaers_data_df.dtypes
# Out:
# VAERS_ID          int64
# AGE_YRS         float64
# SEX              object
# DIED             object
# L_THREAT         object
# ER_VISIT         object
# HOSPITAL         object
# DISABLE          object
# BIRTH_DEFECT     object
# dtype: object

# %%
# Adding bins and labels to the AGE_BIN column
clean_vaers_data_df['AGE_BIN'] = pd.cut(clean_vaers_data_df['AGE_YRS'], bins, labels =labels)
clean_vaers_data_df.head()
# Out:
#    VAERS_ID  AGE_YRS SEX DIED L_THREAT ER_VISIT HOSPITAL DISABLE BIRTH_DEFECT  \
# 0    916600     33.0   F    N        N        N        N       N            N
# 1    916601     73.0   F    N        N        N        N       N            N
# 2    916602     23.0   F    N        N        N        N       N            N
# 3    916603     58.0   F    N        N        N        N       N            N
# 4    916604     47.0   F    N        N        N        N       N            N
#
#   AGE_BIN
# 0   19-40
# 1     60+
# 2   19-40
# 3   41-59
# 4   41-59

# %%
# Set VAERS_ID as index
new_vaers_data_df = clean_vaers_data_df.astype(str).set_index(["VAERS_ID"])
new_vaers_data_df.head()
# Out:
#          AGE_YRS SEX DIED L_THREAT ER_VISIT HOSPITAL DISABLE BIRTH_DEFECT  \
# VAERS_ID
# 916600      33.0   F    N        N        N        N       N            N
# 916601      73.0   F    N        N        N        N       N            N
# 916602      23.0   F    N        N        N        N       N            N
# 916603      58.0   F    N        N        N        N       N            N
# 916604      47.0   F    N        N        N        N       N            N
#
#          AGE_BIN
# VAERS_ID
# 916600     19-40
# 916601       60+
# 916602     19-40
# 916603     41-59
# 916604     41-59

# %%
# Export Clean VAERSData to CSV for join in Postgres
new_vaers_data_df.to_csv(r'clean_vaers_data.csv', index=True)

# %% [raw]
# VAERSVAX Cleanup

# %%
# VAERSVAX Dataframe
vaers_vax = pd.read_csv(vax_csv, index_col=None, header=0, encoding='latin1', low_memory=False)
vaers_vax.head()
# Out:
#    VAERS_ID VAX_TYPE         VAX_MANU  VAX_LOT VAX_DOSE_SERIES VAX_ROUTE  \
# 0    916600  COVID19          MODERNA  037K20A               1        IM
# 1    916601  COVID19          MODERNA  025L20A               1        IM
# 2    916602  COVID19  PFIZER\BIONTECH   EL1284               1        IM
# 3    916603  COVID19          MODERNA  unknown             UNK       NaN
# 4    916604  COVID19          MODERNA      NaN               1        IM
#
#   VAX_SITE                             VAX_NAME
# 0       LA          COVID19 (COVID19 (MODERNA))
# 1       RA          COVID19 (COVID19 (MODERNA))
# 2       LA  COVID19 (COVID19 (PFIZER-BIONTECH))
# 3      NaN          COVID19 (COVID19 (MODERNA))
# 4       LA          COVID19 (COVID19 (MODERNA))

# %%
# Check Columns
vaers_vax.columns
# Out:
# Index(['VAERS_ID', 'VAX_TYPE', 'VAX_MANU', 'VAX_LOT', 'VAX_DOSE_SERIES',
#        'VAX_ROUTE', 'VAX_SITE', 'VAX_NAME'],
#       dtype='object')

# %%
# Drop  Columns 
vaers_vax_df = vaers_vax.astype(str).drop(columns =['VAX_LOT', 'VAX_DOSE_SERIES', 'VAX_ROUTE', 'VAX_SITE'])
vaers_vax_df
# Out:
#        VAERS_ID VAX_TYPE              VAX_MANU  \
# 0        916600  COVID19               MODERNA
# 1        916601  COVID19               MODERNA
# 2        916602  COVID19       PFIZER\BIONTECH
# 3        916603  COVID19               MODERNA
# 4        916604  COVID19               MODERNA
# ...         ...      ...                   ...
# 762757  1939089     FLU4        SANOFI PASTEUR
# 762758  1939102  COVID19       PFIZER\BIONTECH
# 762759  1939113  COVID19       PFIZER\BIONTECH
# 762760  1939114      UNK  UNKNOWN MANUFACTURER
# 762761  1939125      UNK  UNKNOWN MANUFACTURER
#
#                                            VAX_NAME
# 0                       COVID19 (COVID19 (MODERNA))
# 1                       COVID19 (COVID19 (MODERNA))
# 2               COVID19 (COVID19 (PFIZER-BIONTECH))
# 3                       COVID19 (COVID19 (MODERNA))
# 4                       COVID19 (COVID19 (MODERNA))
# ...                                             ...
# 762757  INFLUENZA (SEASONAL) (FLUZONE QUADRIVALENT)
# 762758          COVID19 (COVID19 (PFIZER-BIONTECH))
# 762759          COVID19 (COVID19 (PFIZER-BIONTECH))
# 762760                VACCINE NOT SPECIFIED (OTHER)
# 762761                VACCINE NOT SPECIFIED (OTHER)
#
# [762762 rows x 4 columns]

# %%
# Set VAERS_ID as index
vaers_vax_df = vaers_vax_df.set_index(["VAERS_ID"])
vaers_vax_df
# Out:
#          VAX_TYPE              VAX_MANU  \
# VAERS_ID
# 916600    COVID19               MODERNA
# 916601    COVID19               MODERNA
# 916602    COVID19       PFIZER\BIONTECH
# 916603    COVID19               MODERNA
# 916604    COVID19               MODERNA
# ...           ...                   ...
# 1939089      FLU4        SANOFI PASTEUR
# 1939102   COVID19       PFIZER\BIONTECH
# 1939113   COVID19       PFIZER\BIONTECH
# 1939114       UNK  UNKNOWN MANUFACTURER
# 1939125       UNK  UNKNOWN MANUFACTURER
#
#                                              VAX_NAME
# VAERS_ID
# 916600                    COVID19 (COVID19 (MODERNA))
# 916601                    COVID19 (COVID19 (MODERNA))
# 916602            COVID19 (COVID19 (PFIZER-BIONTECH))
# 916603                    COVID19 (COVID19 (MODERNA))
# 916604                    COVID19 (COVID19 (MODERNA))
# ...                                               ...
# 1939089   INFLUENZA (SEASONAL) (FLUZONE QUADRIVALENT)
# 1939102           COVID19 (COVID19 (PFIZER-BIONTECH))
# 1939113           COVID19 (COVID19 (PFIZER-BIONTECH))
# 1939114                 VACCINE NOT SPECIFIED (OTHER)
# 1939125                 VACCINE NOT SPECIFIED (OTHER)
#
# [762762 rows x 3 columns]

# %%
# Importing 2021VAERSSYMPTOMS.csv 
vaers_symptoms_df = pd.read_csv(symptoms_csv, index_col=None, header=0, encoding='latin1', low_memory=False)
vaers_symptoms_df
# Out:
#         VAERS_ID                    SYMPTOM1  SYMPTOMVERSION1  \
# 0         916600                   Dysphagia             23.1
# 1         916601                     Anxiety             23.1
# 2         916602            Chest discomfort             23.1
# 3         916603                   Dizziness             23.1
# 4         916604     Injection site erythema             23.1
# ...          ...                         ...              ...
# 964616   1939113               Adverse event             24.1
# 964617   1939114                  Chest pain             24.1
# 964618   1939114               Muscle spasms             24.1
# 964619   1939125                     Ageusia             24.1
# 964620   1939125  Magnetic resonance imaging             24.1
#
#                        SYMPTOM2  SYMPTOMVERSION2                 SYMPTOM3  \
# 0                  Epiglottitis             23.1                      NaN
# 1                      Dyspnoea             23.1                      NaN
# 2                     Dysphagia             23.1        Pain in extremity
# 3                       Fatigue             23.1       Mobility decreased
# 4       Injection site pruritus             23.1  Injection site swelling
# ...                         ...              ...                      ...
# 964616                      NaN              NaN                      NaN
# 964617                   Chills             24.1                    Cough
# 964618                     Pain             24.1                  Pyrexia
# 964619               Blood test             24.1    Computerised tomogram
# 964620         Weight decreased             24.1                      NaN
#
#         SYMPTOMVERSION3               SYMPTOM4  SYMPTOMVERSION4  \
# 0                   NaN                    NaN              NaN
# 1                   NaN                    NaN              NaN
# 2                  23.1      Visual impairment             23.1
# 3                  23.1                    NaN              NaN
# 4                  23.1  Injection site warmth             23.1
# ...                 ...                    ...              ...
# 964616              NaN                    NaN              NaN
# 964617             24.1               Headache             24.1
# 964618             24.1                    NaN              NaN
# 964619             24.1     Decreased appetite             24.1
# 964620              NaN                    NaN              NaN
#
#                    SYMPTOM5  SYMPTOMVERSION5
# 0                       NaN              NaN
# 1                       NaN              NaN
# 2                       NaN              NaN
# 3                       NaN              NaN
# 4                       NaN              NaN
# ...                     ...              ...
# 964616                  NaN              NaN
# 964617  Injection site rash             24.1
# 964618                  NaN              NaN
# 964619           Hypophagia             24.1
# 964620                  NaN              NaN
#
# [964621 rows x 11 columns]

# %%
# Dropping the SYMPTOMVERSION columns
new_vaers_symptoms_df = vaers_symptoms_df.drop(columns =['SYMPTOMVERSION1', 'SYMPTOMVERSION2', 'SYMPTOMVERSION3', 'SYMPTOMVERSION4', 'SYMPTOMVERSION5'])
new_vaers_symptoms_df.head()
# Out:
#    VAERS_ID                 SYMPTOM1                 SYMPTOM2  \
# 0    916600                Dysphagia             Epiglottitis
# 1    916601                  Anxiety                 Dyspnoea
# 2    916602         Chest discomfort                Dysphagia
# 3    916603                Dizziness                  Fatigue
# 4    916604  Injection site erythema  Injection site pruritus
#
#                   SYMPTOM3               SYMPTOM4 SYMPTOM5
# 0                      NaN                    NaN      NaN
# 1                      NaN                    NaN      NaN
# 2        Pain in extremity      Visual impairment      NaN
# 3       Mobility decreased                    NaN      NaN
# 4  Injection site swelling  Injection site warmth      NaN

# %%
# converting NaN to 0 in symptoms df
new_vaers_symptoms_df = new_vaers_symptoms_df.fillna(0)
new_vaers_symptoms_df
# Out:
#         VAERS_ID                    SYMPTOM1                 SYMPTOM2  \
# 0         916600                   Dysphagia             Epiglottitis
# 1         916601                     Anxiety                 Dyspnoea
# 2         916602            Chest discomfort                Dysphagia
# 3         916603                   Dizziness                  Fatigue
# 4         916604     Injection site erythema  Injection site pruritus
# ...          ...                         ...                      ...
# 964616   1939113               Adverse event                        0
# 964617   1939114                  Chest pain                   Chills
# 964618   1939114               Muscle spasms                     Pain
# 964619   1939125                     Ageusia               Blood test
# 964620   1939125  Magnetic resonance imaging         Weight decreased
#
#                        SYMPTOM3               SYMPTOM4             SYMPTOM5
# 0                             0                      0                    0
# 1                             0                      0                    0
# 2             Pain in extremity      Visual impairment                    0
# 3            Mobility decreased                      0                    0
# 4       Injection site swelling  Injection site warmth                    0
# ...                         ...                    ...                  ...
# 964616                        0                      0                    0
# 964617                    Cough               Headache  Injection site rash
# 964618                  Pyrexia                      0                    0
# 964619    Computerised tomogram     Decreased appetite           Hypophagia
# 964620                        0                      0                    0
#
# [964621 rows x 6 columns]

# %%
# checking if it worked. yup it worked.
vaers_symptoms_df.isnull().sum()
# Out:
# VAERS_ID                0
# SYMPTOM1                0
# SYMPTOMVERSION1         0
# SYMPTOM2           215678
# SYMPTOMVERSION2    215678
# SYMPTOM3           390150
# SYMPTOMVERSION3    390150
# SYMPTOM4           527861
# SYMPTOMVERSION4    527861
# SYMPTOM5           637769
# SYMPTOMVERSION5    637769
# dtype: int64

# %%
# Checking the data types
new_vaers_symptoms_df.dtypes
# Out:
# VAERS_ID     int64
# SYMPTOM1    object
# SYMPTOM2    object
# SYMPTOM3    object
# SYMPTOM4    object
# SYMPTOM5    object
# dtype: object

# %%
# Verifying the columns on the dataframe
new_vaers_symptoms_df.columns
# Out:
# Index(['VAERS_ID', 'SYMPTOM1', 'SYMPTOM2', 'SYMPTOM3', 'SYMPTOM4', 'SYMPTOM5'], dtype='object')

# %%
# Set VAERS_ID as index
clean_vaers_symptoms_df = new_vaers_symptoms_df.astype(str).set_index(["VAERS_ID"])
clean_vaers_symptoms_df
# Out:
#                             SYMPTOM1                 SYMPTOM2  \
# VAERS_ID
# 916600                     Dysphagia             Epiglottitis
# 916601                       Anxiety                 Dyspnoea
# 916602              Chest discomfort                Dysphagia
# 916603                     Dizziness                  Fatigue
# 916604       Injection site erythema  Injection site pruritus
# ...                              ...                      ...
# 1939113                Adverse event                        0
# 1939114                   Chest pain                   Chills
# 1939114                Muscle spasms                     Pain
# 1939125                      Ageusia               Blood test
# 1939125   Magnetic resonance imaging         Weight decreased
#
#                          SYMPTOM3               SYMPTOM4             SYMPTOM5
# VAERS_ID
# 916600                          0                      0                    0
# 916601                          0                      0                    0
# 916602          Pain in extremity      Visual impairment                    0
# 916603         Mobility decreased                      0                    0
# 916604    Injection site swelling  Injection site warmth                    0
# ...                           ...                    ...                  ...
# 1939113                         0                      0                    0
# 1939114                     Cough               Headache  Injection site rash
# 1939114                   Pyrexia                      0                    0
# 1939125     Computerised tomogram     Decreased appetite           Hypophagia
# 1939125                         0                      0                    0
#
# [964621 rows x 5 columns]

# %%
# Grouping SYMPTOM1 column by VAERS_ID and joingin the values
grouped_symptoms1 = new_vaers_symptoms_df.astype(str).groupby('VAERS_ID', as_index=False)['SYMPTOM1'].apply(', '.join)
grouped_symptoms1
# Out:
#        VAERS_ID          SYMPTOM1
# 0       1000000          COVID-19
# 1       1000001          COVID-19
# 2       1000002   Lymphadenopathy
# 3       1000003              Rash
# 4       1000004     Rash pruritic
# ...         ...               ...
# 721462   999995          COVID-19
# 721463   999996          COVID-19
# 721464   999997          COVID-19
# 721465   999998  Hypersensitivity
# 721466   999999  Feeling abnormal
#
# [721467 rows x 2 columns]

# %%
# Setting VAERS_ID as the index
grouped_symptoms1 = grouped_symptoms1.set_index(["VAERS_ID"])
grouped_symptoms1
# Out:
#                   SYMPTOM1
# VAERS_ID
# 1000000           COVID-19
# 1000001           COVID-19
# 1000002    Lymphadenopathy
# 1000003               Rash
# 1000004      Rash pruritic
# ...                    ...
# 999995            COVID-19
# 999996            COVID-19
# 999997            COVID-19
# 999998    Hypersensitivity
# 999999    Feeling abnormal
#
# [721467 rows x 1 columns]

# %%
# Grouping SYMPTOM2 column by VAERS_ID and joingin the values
grouped_symptoms2 = new_vaers_symptoms_df.astype(str).groupby('VAERS_ID', as_index=False)['SYMPTOM2'].apply(', '.join)
grouped_symptoms2
# Out:
#        VAERS_ID                  SYMPTOM2
# 0       1000000  SARS-CoV-2 test positive
# 1       1000001  SARS-CoV-2 test positive
# 2       1000002                         0
# 3       1000003                 Urticaria
# 4       1000004                         0
# ...         ...                       ...
# 721462   999995  SARS-CoV-2 test positive
# 721463   999996  SARS-CoV-2 test positive
# 721464   999997                     Cough
# 721465   999998                  Pruritus
# 721466   999999                  Headache
#
# [721467 rows x 2 columns]

# %%
# Setting VAERS_ID as the index
grouped_symptoms2 = grouped_symptoms2.set_index(["VAERS_ID"])
grouped_symptoms2
# Out:
#                           SYMPTOM2
# VAERS_ID
# 1000000   SARS-CoV-2 test positive
# 1000001   SARS-CoV-2 test positive
# 1000002                          0
# 1000003                  Urticaria
# 1000004                          0
# ...                            ...
# 999995    SARS-CoV-2 test positive
# 999996    SARS-CoV-2 test positive
# 999997                       Cough
# 999998                    Pruritus
# 999999                    Headache
#
# [721467 rows x 1 columns]

# %%
# Grouping SYMPTOM3 column by VAERS_ID and joingin the values
grouped_symptoms3 = new_vaers_symptoms_df.astype(str).groupby('VAERS_ID', as_index=False)['SYMPTOM3'].apply(', '.join)
grouped_symptoms3
# Out:
#        VAERS_ID                  SYMPTOM3
# 0       1000000                         0
# 1       1000001                         0
# 2       1000002                         0
# 3       1000003                         0
# 4       1000004                         0
# ...         ...                       ...
# 721462   999995                         0
# 721463   999996                         0
# 721464   999997  SARS-CoV-2 test positive
# 721465   999998                 Urticaria
# 721466   999999                  Lethargy
#
# [721467 rows x 2 columns]

# %%
# Setting VAERS_ID as the index
grouped_symptoms3 = grouped_symptoms3.set_index(["VAERS_ID"])
grouped_symptoms3
# Out:
#                           SYMPTOM3
# VAERS_ID
# 1000000                          0
# 1000001                          0
# 1000002                          0
# 1000003                          0
# 1000004                          0
# ...                            ...
# 999995                           0
# 999996                           0
# 999997    SARS-CoV-2 test positive
# 999998                   Urticaria
# 999999                    Lethargy
#
# [721467 rows x 1 columns]

# %%
# Grouping SYMPTOM4 column by VAERS_ID and joingin the values
grouped_symptoms4 = new_vaers_symptoms_df.astype(str).groupby('VAERS_ID', as_index=False)['SYMPTOM4'].apply(', '.join)
grouped_symptoms4
# Out:
#        VAERS_ID SYMPTOM4
# 0       1000000        0
# 1       1000001        0
# 2       1000002        0
# 3       1000003        0
# 4       1000004        0
# ...         ...      ...
# 721462   999995        0
# 721463   999996        0
# 721464   999997        0
# 721465   999998        0
# 721466   999999        0
#
# [721467 rows x 2 columns]

# %%
# Setting VAERS_ID as the index
grouped_symptoms4 = grouped_symptoms4.set_index(["VAERS_ID"])
grouped_symptoms4
# Out:
#          SYMPTOM4
# VAERS_ID
# 1000000         0
# 1000001         0
# 1000002         0
# 1000003         0
# 1000004         0
# ...           ...
# 999995          0
# 999996          0
# 999997          0
# 999998          0
# 999999          0
#
# [721467 rows x 1 columns]

# %%
# Grouping SYMPTOM5 column by VAERS_ID and joingin the values
grouped_symptoms5 = new_vaers_symptoms_df.astype(str).groupby('VAERS_ID', as_index=False)['SYMPTOM5'].apply(', '.join)
grouped_symptoms5
# Out:
#        VAERS_ID SYMPTOM5
# 0       1000000        0
# 1       1000001        0
# 2       1000002        0
# 3       1000003        0
# 4       1000004        0
# ...         ...      ...
# 721462   999995        0
# 721463   999996        0
# 721464   999997        0
# 721465   999998        0
# 721466   999999        0
#
# [721467 rows x 2 columns]

# %%
# Setting VAERS_ID as the index
grouped_symptoms5 = grouped_symptoms5.set_index(["VAERS_ID"])
grouped_symptoms5
# Out:
#          SYMPTOM5
# VAERS_ID
# 1000000         0
# 1000001         0
# 1000002         0
# 1000003         0
# 1000004         0
# ...           ...
# 999995          0
# 999996          0
# 999997          0
# 999998          0
# 999999          0
#
# [721467 rows x 1 columns]

# %%
# Merging Symptoms 1 and 2 by VAERS_ID
merge_1_2 = pd.merge(grouped_symptoms1, grouped_symptoms2, how="left", on=["VAERS_ID"])
merge_1_2
# Out:
#                   SYMPTOM1                  SYMPTOM2
# VAERS_ID
# 1000000           COVID-19  SARS-CoV-2 test positive
# 1000001           COVID-19  SARS-CoV-2 test positive
# 1000002    Lymphadenopathy                         0
# 1000003               Rash                 Urticaria
# 1000004      Rash pruritic                         0
# ...                    ...                       ...
# 999995            COVID-19  SARS-CoV-2 test positive
# 999996            COVID-19  SARS-CoV-2 test positive
# 999997            COVID-19                     Cough
# 999998    Hypersensitivity                  Pruritus
# 999999    Feeling abnormal                  Headache
#
# [721467 rows x 2 columns]

# %%
# Merging Symptoms 3 and 4 by VAERS_ID
merge_3_4 = pd.merge(grouped_symptoms3, grouped_symptoms4, how="left", on=["VAERS_ID"])
merge_3_4
# Out:
#                           SYMPTOM3 SYMPTOM4
# VAERS_ID
# 1000000                          0        0
# 1000001                          0        0
# 1000002                          0        0
# 1000003                          0        0
# 1000004                          0        0
# ...                            ...      ...
# 999995                           0        0
# 999996                           0        0
# 999997    SARS-CoV-2 test positive        0
# 999998                   Urticaria        0
# 999999                    Lethargy        0
#
# [721467 rows x 2 columns]

# %%
# Merging Symptoms 1-4
merge_df = pd.merge(merge_1_2, merge_3_4, how="left", on=["VAERS_ID"])
merge_df
# Out:
#                   SYMPTOM1                  SYMPTOM2  \
# VAERS_ID
# 1000000           COVID-19  SARS-CoV-2 test positive
# 1000001           COVID-19  SARS-CoV-2 test positive
# 1000002    Lymphadenopathy                         0
# 1000003               Rash                 Urticaria
# 1000004      Rash pruritic                         0
# ...                    ...                       ...
# 999995            COVID-19  SARS-CoV-2 test positive
# 999996            COVID-19  SARS-CoV-2 test positive
# 999997            COVID-19                     Cough
# 999998    Hypersensitivity                  Pruritus
# 999999    Feeling abnormal                  Headache
#
#                           SYMPTOM3 SYMPTOM4
# VAERS_ID
# 1000000                          0        0
# 1000001                          0        0
# 1000002                          0        0
# 1000003                          0        0
# 1000004                          0        0
# ...                            ...      ...
# 999995                           0        0
# 999996                           0        0
# 999997    SARS-CoV-2 test positive        0
# 999998                   Urticaria        0
# 999999                    Lethargy        0
#
# [721467 rows x 4 columns]

# %%
# Merging all symptom columns into one df
full_df_merge = pd.merge(merge_df, grouped_symptoms5, how="left", on=["VAERS_ID"])
full_df_merge
# Out:
#                   SYMPTOM1                  SYMPTOM2  \
# VAERS_ID
# 1000000           COVID-19  SARS-CoV-2 test positive
# 1000001           COVID-19  SARS-CoV-2 test positive
# 1000002    Lymphadenopathy                         0
# 1000003               Rash                 Urticaria
# 1000004      Rash pruritic                         0
# ...                    ...                       ...
# 999995            COVID-19  SARS-CoV-2 test positive
# 999996            COVID-19  SARS-CoV-2 test positive
# 999997            COVID-19                     Cough
# 999998    Hypersensitivity                  Pruritus
# 999999    Feeling abnormal                  Headache
#
#                           SYMPTOM3 SYMPTOM4 SYMPTOM5
# VAERS_ID
# 1000000                          0        0        0
# 1000001                          0        0        0
# 1000002                          0        0        0
# 1000003                          0        0        0
# 1000004                          0        0        0
# ...                            ...      ...      ...
# 999995                           0        0        0
# 999996                           0        0        0
# 999997    SARS-CoV-2 test positive        0        0
# 999998                   Urticaria        0        0
# 999999                    Lethargy        0        0
#
# [721467 rows x 5 columns]

# %%
# using merge function by setting how='inner'
vax_symp_join = pd.merge(vaers_vax_df, full_df_merge, 
                   on='VAERS_ID', 
                   how='inner')
vax_symp_join
# Out:
#          VAX_TYPE              VAX_MANU  \
# VAERS_ID
# 916600    COVID19               MODERNA
# 916601    COVID19               MODERNA
# 916602    COVID19       PFIZER\BIONTECH
# 916603    COVID19               MODERNA
# 916604    COVID19               MODERNA
# ...           ...                   ...
# 1939089      FLU4        SANOFI PASTEUR
# 1939102   COVID19       PFIZER\BIONTECH
# 1939113   COVID19       PFIZER\BIONTECH
# 1939114       UNK  UNKNOWN MANUFACTURER
# 1939125       UNK  UNKNOWN MANUFACTURER
#
#                                              VAX_NAME  \
# VAERS_ID
# 916600                    COVID19 (COVID19 (MODERNA))
# 916601                    COVID19 (COVID19 (MODERNA))
# 916602            COVID19 (COVID19 (PFIZER-BIONTECH))
# 916603                    COVID19 (COVID19 (MODERNA))
# 916604                    COVID19 (COVID19 (MODERNA))
# ...                                               ...
# 1939089   INFLUENZA (SEASONAL) (FLUZONE QUADRIVALENT)
# 1939102           COVID19 (COVID19 (PFIZER-BIONTECH))
# 1939113           COVID19 (COVID19 (PFIZER-BIONTECH))
# 1939114                 VACCINE NOT SPECIFIED (OTHER)
# 1939125                 VACCINE NOT SPECIFIED (OTHER)
#
#                                      SYMPTOM1                      SYMPTOM2  \
# VAERS_ID
# 916600                              Dysphagia                  Epiglottitis
# 916601                                Anxiety                      Dyspnoea
# 916602                       Chest discomfort                     Dysphagia
# 916603                              Dizziness                       Fatigue
# 916604                Injection site erythema       Injection site pruritus
# ...                                       ...                           ...
# 1939089                            Arthralgia           Injection site pain
# 1939102                       Lymph node pain               Lymphadenopathy
# 1939113                         Adverse event                             0
# 1939114             Chest pain, Muscle spasms                  Chills, Pain
# 1939125   Ageusia, Magnetic resonance imaging  Blood test, Weight decreased
#
#                           SYMPTOM3               SYMPTOM4  \
# VAERS_ID
# 916600                           0                      0
# 916601                           0                      0
# 916602           Pain in extremity      Visual impairment
# 916603          Mobility decreased                      0
# 916604     Injection site swelling  Injection site warmth
# ...                            ...                    ...
# 1939089          Pain in extremity                      0
# 1939102                     Nodule                      0
# 1939113                          0                      0
# 1939114             Cough, Pyrexia            Headache, 0
# 1939125   Computerised tomogram, 0  Decreased appetite, 0
#
#                         SYMPTOM5
# VAERS_ID
# 916600                         0
# 916601                         0
# 916602                         0
# 916603                         0
# 916604                         0
# ...                          ...
# 1939089                        0
# 1939102                        0
# 1939113                        0
# 1939114   Injection site rash, 0
# 1939125            Hypophagia, 0
#
# [762759 rows x 8 columns]

# %%
# Remove duplicates
clean_vax_symp = vax_symp_join.drop_duplicates()
clean_vax_symp
# Out:
#          VAX_TYPE              VAX_MANU  \
# VAERS_ID
# 916600    COVID19               MODERNA
# 916601    COVID19               MODERNA
# 916602    COVID19       PFIZER\BIONTECH
# 916603    COVID19               MODERNA
# 916604    COVID19               MODERNA
# ...           ...                   ...
# 1939081   COVID19       PFIZER\BIONTECH
# 1939089      FLU4        SANOFI PASTEUR
# 1939102   COVID19       PFIZER\BIONTECH
# 1939114       UNK  UNKNOWN MANUFACTURER
# 1939125       UNK  UNKNOWN MANUFACTURER
#
#                                              VAX_NAME  \
# VAERS_ID
# 916600                    COVID19 (COVID19 (MODERNA))
# 916601                    COVID19 (COVID19 (MODERNA))
# 916602            COVID19 (COVID19 (PFIZER-BIONTECH))
# 916603                    COVID19 (COVID19 (MODERNA))
# 916604                    COVID19 (COVID19 (MODERNA))
# ...                                               ...
# 1939081           COVID19 (COVID19 (PFIZER-BIONTECH))
# 1939089   INFLUENZA (SEASONAL) (FLUZONE QUADRIVALENT)
# 1939102           COVID19 (COVID19 (PFIZER-BIONTECH))
# 1939114                 VACCINE NOT SPECIFIED (OTHER)
# 1939125                 VACCINE NOT SPECIFIED (OTHER)
#
#                                               SYMPTOM1  \
# VAERS_ID
# 916600                                       Dysphagia
# 916601                                         Anxiety
# 916602                                Chest discomfort
# 916603                                       Dizziness
# 916604                         Injection site erythema
# ...                                                ...
# 1939081   COVID-19, Headache, SARS-CoV-2 test positive
# 1939089                                     Arthralgia
# 1939102                                Lymph node pain
# 1939114                      Chest pain, Muscle spasms
# 1939125            Ageusia, Magnetic resonance imaging
#
#                               SYMPTOM2                      SYMPTOM3  \
# VAERS_ID
# 916600                    Epiglottitis                             0
# 916601                        Dyspnoea                             0
# 916602                       Dysphagia             Pain in extremity
# 916603                         Fatigue            Mobility decreased
# 916604         Injection site pruritus       Injection site swelling
# ...                                ...                           ...
# 1939081             Chills, Myalgia, 0  Cough, Oropharyngeal pain, 0
# 1939089            Injection site pain             Pain in extremity
# 1939102                Lymphadenopathy                        Nodule
# 1939114                   Chills, Pain                Cough, Pyrexia
# 1939125   Blood test, Weight decreased      Computerised tomogram, 0
#
#                        SYMPTOM4                 SYMPTOM5
# VAERS_ID
# 916600                        0                        0
# 916601                        0                        0
# 916602        Visual impairment                        0
# 916603                        0                        0
# 916604    Injection site warmth                        0
# ...                         ...                      ...
# 1939081    Dyspnoea, Pyrexia, 0  Fatigue, Rhinorrhoea, 0
# 1939089                       0                        0
# 1939102                       0                        0
# 1939114             Headache, 0   Injection site rash, 0
# 1939125   Decreased appetite, 0            Hypophagia, 0
#
# [407125 rows x 8 columns]

# %%
# Verify Columns of vax_symp_join 
list(clean_vax_symp.columns)
# Out:
# ['VAX_TYPE',
#  'VAX_MANU',
#  'VAX_NAME',
#  'SYMPTOM1',
#  'SYMPTOM2',
#  'SYMPTOM3',
#  'SYMPTOM4',
#  'SYMPTOM5']

# %%
new_vax_symp = clean_vax_symp.fillna(0)
new_vax_symp
# Out:
#          VAX_TYPE              VAX_MANU  \
# VAERS_ID
# 916600    COVID19               MODERNA
# 916601    COVID19               MODERNA
# 916602    COVID19       PFIZER\BIONTECH
# 916603    COVID19               MODERNA
# 916604    COVID19               MODERNA
# ...           ...                   ...
# 1939081   COVID19       PFIZER\BIONTECH
# 1939089      FLU4        SANOFI PASTEUR
# 1939102   COVID19       PFIZER\BIONTECH
# 1939114       UNK  UNKNOWN MANUFACTURER
# 1939125       UNK  UNKNOWN MANUFACTURER
#
#                                              VAX_NAME  \
# VAERS_ID
# 916600                    COVID19 (COVID19 (MODERNA))
# 916601                    COVID19 (COVID19 (MODERNA))
# 916602            COVID19 (COVID19 (PFIZER-BIONTECH))
# 916603                    COVID19 (COVID19 (MODERNA))
# 916604                    COVID19 (COVID19 (MODERNA))
# ...                                               ...
# 1939081           COVID19 (COVID19 (PFIZER-BIONTECH))
# 1939089   INFLUENZA (SEASONAL) (FLUZONE QUADRIVALENT)
# 1939102           COVID19 (COVID19 (PFIZER-BIONTECH))
# 1939114                 VACCINE NOT SPECIFIED (OTHER)
# 1939125                 VACCINE NOT SPECIFIED (OTHER)
#
#                                               SYMPTOM1  \
# VAERS_ID
# 916600                                       Dysphagia
# 916601                                         Anxiety
# 916602                                Chest discomfort
# 916603                                       Dizziness
# 916604                         Injection site erythema
# ...                                                ...
# 1939081   COVID-19, Headache, SARS-CoV-2 test positive
# 1939089                                     Arthralgia
# 1939102                                Lymph node pain
# 1939114                      Chest pain, Muscle spasms
# 1939125            Ageusia, Magnetic resonance imaging
#
#                               SYMPTOM2                      SYMPTOM3  \
# VAERS_ID
# 916600                    Epiglottitis                             0
# 916601                        Dyspnoea                             0
# 916602                       Dysphagia             Pain in extremity
# 916603                         Fatigue            Mobility decreased
# 916604         Injection site pruritus       Injection site swelling
# ...                                ...                           ...
# 1939081             Chills, Myalgia, 0  Cough, Oropharyngeal pain, 0
# 1939089            Injection site pain             Pain in extremity
# 1939102                Lymphadenopathy                        Nodule
# 1939114                   Chills, Pain                Cough, Pyrexia
# 1939125   Blood test, Weight decreased      Computerised tomogram, 0
#
#                        SYMPTOM4                 SYMPTOM5
# VAERS_ID
# 916600                        0                        0
# 916601                        0                        0
# 916602        Visual impairment                        0
# 916603                        0                        0
# 916604    Injection site warmth                        0
# ...                         ...                      ...
# 1939081    Dyspnoea, Pyrexia, 0  Fatigue, Rhinorrhoea, 0
# 1939089                       0                        0
# 1939102                       0                        0
# 1939114             Headache, 0   Injection site rash, 0
# 1939125   Decreased appetite, 0            Hypophagia, 0
#
# [407125 rows x 8 columns]

# %%
clean_vax_symp.isnull().sum()
# Out:
# VAX_TYPE    0
# VAX_MANU    0
# VAX_NAME    0
# SYMPTOM1    0
# SYMPTOM2    0
# SYMPTOM3    0
# SYMPTOM4    0
# SYMPTOM5    0
# dtype: int64

# %%
# check to make sure only covid vaccines are in the list
covid_list = clean_vax_symp['VAX_MANU'].unique()
covid_list
# Out:
# array(['MODERNA', 'PFIZER\\BIONTECH', 'SEQIRUS, INC.',
#        'GLAXOSMITHKLINE BIOLOGICALS', 'MERCK & CO. INC.', 'PFIZER\\WYETH',
#        'UNKNOWN MANUFACTURER', 'SANOFI PASTEUR',
#        'NOVARTIS VACCINES AND DIAGNOSTICS',
#        'PROTEIN SCIENCES CORPORATION', 'EMERGENT BIOSOLUTIONS',
#        'MEDIMMUNE VACCINES, INC.', 'TEVA PHARMACEUTICALS',
#        'DYNAVAX TECHNOLOGIES CORPORATION', 'PAXVAX',
#        'MASS. PUB HLTH BIOL LAB', 'BERNA BIOTECH, LTD.', 'CSL LIMITED',
#        'INTERCELL AG', 'JANSSEN', 'PASTEUR MERIEUX CONNAUGHT',
#        'SMITHKLINE BEECHAM', 'MSP VACCINE COMPANY'], dtype=object)

# %%
covid_df = clean_vax_symp.astype(str)[clean_vax_symp.astype(str)["VAX_TYPE"] == 'COVID19']
covid_df.head()
# Out:
#          VAX_TYPE         VAX_MANU                             VAX_NAME  \
# VAERS_ID
# 916600    COVID19          MODERNA          COVID19 (COVID19 (MODERNA))
# 916601    COVID19          MODERNA          COVID19 (COVID19 (MODERNA))
# 916602    COVID19  PFIZER\BIONTECH  COVID19 (COVID19 (PFIZER-BIONTECH))
# 916603    COVID19          MODERNA          COVID19 (COVID19 (MODERNA))
# 916604    COVID19          MODERNA          COVID19 (COVID19 (MODERNA))
#
#                          SYMPTOM1                 SYMPTOM2  \
# VAERS_ID
# 916600                  Dysphagia             Epiglottitis
# 916601                    Anxiety                 Dyspnoea
# 916602           Chest discomfort                Dysphagia
# 916603                  Dizziness                  Fatigue
# 916604    Injection site erythema  Injection site pruritus
#
#                          SYMPTOM3               SYMPTOM4 SYMPTOM5
# VAERS_ID
# 916600                          0                      0        0
# 916601                          0                      0        0
# 916602          Pain in extremity      Visual impairment        0
# 916603         Mobility decreased                      0        0
# 916604    Injection site swelling  Injection site warmth        0

# %%
covid_df.to_csv(r'VAERS_Vax_Symptoms.csv', index=True)

# %% [raw]
# Machine Learning Cleanup

# %%
#merge vaxsymp with l threat
ml_data_merge = pd.merge(clean_vaers_symptoms_df,vaers_vax_df, on='VAERS_ID', how='left')
ml_data_merge
# Out:
#                             SYMPTOM1                 SYMPTOM2  \
# VAERS_ID
# 916600                     Dysphagia             Epiglottitis
# 916601                       Anxiety                 Dyspnoea
# 916602              Chest discomfort                Dysphagia
# 916603                     Dizziness                  Fatigue
# 916604       Injection site erythema  Injection site pruritus
# ...                              ...                      ...
# 1939113                Adverse event                        0
# 1939114                   Chest pain                   Chills
# 1939114                Muscle spasms                     Pain
# 1939125                      Ageusia               Blood test
# 1939125   Magnetic resonance imaging         Weight decreased
#
#                          SYMPTOM3               SYMPTOM4             SYMPTOM5  \
# VAERS_ID
# 916600                          0                      0                    0
# 916601                          0                      0                    0
# 916602          Pain in extremity      Visual impairment                    0
# 916603         Mobility decreased                      0                    0
# 916604    Injection site swelling  Injection site warmth                    0
# ...                           ...                    ...                  ...
# 1939113                         0                      0                    0
# 1939114                     Cough               Headache  Injection site rash
# 1939114                   Pyrexia                      0                    0
# 1939125     Computerised tomogram     Decreased appetite           Hypophagia
# 1939125                         0                      0                    0
#
#          VAX_TYPE              VAX_MANU                             VAX_NAME
# VAERS_ID
# 916600    COVID19               MODERNA          COVID19 (COVID19 (MODERNA))
# 916601    COVID19               MODERNA          COVID19 (COVID19 (MODERNA))
# 916602    COVID19       PFIZER\BIONTECH  COVID19 (COVID19 (PFIZER-BIONTECH))
# 916603    COVID19               MODERNA          COVID19 (COVID19 (MODERNA))
# 916604    COVID19               MODERNA          COVID19 (COVID19 (MODERNA))
# ...           ...                   ...                                  ...
# 1939113   COVID19       PFIZER\BIONTECH  COVID19 (COVID19 (PFIZER-BIONTECH))
# 1939114       UNK  UNKNOWN MANUFACTURER        VACCINE NOT SPECIFIED (OTHER)
# 1939114       UNK  UNKNOWN MANUFACTURER        VACCINE NOT SPECIFIED (OTHER)
# 1939125       UNK  UNKNOWN MANUFACTURER        VACCINE NOT SPECIFIED (OTHER)
# 1939125       UNK  UNKNOWN MANUFACTURER        VACCINE NOT SPECIFIED (OTHER)
#
# [1026542 rows x 8 columns]

# %%
ml_data_merge1 = pd.merge(ml_data_merge,new_vaers_data_df, on='VAERS_ID', how='left')
ml_data_merge1.head()
# Out:
#                          SYMPTOM1                 SYMPTOM2  \
# VAERS_ID
# 916600                  Dysphagia             Epiglottitis
# 916601                    Anxiety                 Dyspnoea
# 916602           Chest discomfort                Dysphagia
# 916603                  Dizziness                  Fatigue
# 916604    Injection site erythema  Injection site pruritus
#
#                          SYMPTOM3               SYMPTOM4 SYMPTOM5 VAX_TYPE  \
# VAERS_ID
# 916600                          0                      0        0  COVID19
# 916601                          0                      0        0  COVID19
# 916602          Pain in extremity      Visual impairment        0  COVID19
# 916603         Mobility decreased                      0        0  COVID19
# 916604    Injection site swelling  Injection site warmth        0  COVID19
#
#                  VAX_MANU                             VAX_NAME AGE_YRS SEX  \
# VAERS_ID
# 916600            MODERNA          COVID19 (COVID19 (MODERNA))    33.0   F
# 916601            MODERNA          COVID19 (COVID19 (MODERNA))    73.0   F
# 916602    PFIZER\BIONTECH  COVID19 (COVID19 (PFIZER-BIONTECH))    23.0   F
# 916603            MODERNA          COVID19 (COVID19 (MODERNA))    58.0   F
# 916604            MODERNA          COVID19 (COVID19 (MODERNA))    47.0   F
#
#          DIED L_THREAT ER_VISIT HOSPITAL DISABLE BIRTH_DEFECT AGE_BIN
# VAERS_ID
# 916600      N        N        N        N       N            N   19-40
# 916601      N        N        N        N       N            N     60+
# 916602      N        N        N        N       N            N   19-40
# 916603      N        N        N        N       N            N   41-59
# 916604      N        N        N        N       N            N   41-59

# %%
# Dropping unnecessary columns
ml_data_merge1 = ml_data_merge1[ml_data_merge1["VAX_TYPE"] == 'COVID19']
ml_ready_df = ml_data_merge1.drop(columns =['VAX_NAME','VAX_TYPE'])
ml_ready_df['L_THREAT'].value_counts()
# Out:
# N    938084
# Y     24484
# Name: L_THREAT, dtype: int64

# %%
# finding the symptoms with the most life threatening risks by narrowing down the dataset by L_THREAT and HOSPITAL
test = ml_ready_df[ml_ready_df.L_THREAT != 'N']
test = test[test.HOSPITAL != 'N']
test
# Out:
#                                        SYMPTOM1  \
# VAERS_ID
# 916710                             Appendicitis
# 916890                              Chest X-ray
# 916890                                Urticaria
# 917210    Blood lactate dehydrogenase increased
# 917210                                    Cough
# ...                                         ...
# 1937227                                  Nausea
# 1938416                               Blindness
# 1938563                       Aortic dissection
# 1938760                              Blood test
# 1938760                         SARS-CoV-2 test
#
#                                       SYMPTOM2                  SYMPTOM3  \
# VAERS_ID
# 916710    Band neutrophil percentage increased                   Surgery
# 916890                                Dyspnoea           Laboratory test
# 916890                                Wheezing                         0
# 917210            C-reactive protein increased      Chest X-ray abnormal
# 917210                               Diarrhoea                  Dyspnoea
# ...                                        ...                       ...
# 1937227                            Photophobia  Subarachnoid haemorrhage
# 1938416               Cerebrovascular accident                         0
# 1938563          Arteriogram coronary abnormal                   Surgery
# 1938760                  Computerised tomogram      Electroencephalogram
# 1938760                                Seizure            Urine analysis
#
#                                   SYMPTOM4                      SYMPTOM5  \
# VAERS_ID
# 916710    White blood cell count increased                             0
# 916890                     SARS-CoV-2 test              Throat tightness
# 916890                                   0                             0
# 917210                              Chills  Computerised tomogram thorax
# 917210               Fibrin D dimer normal            Lung consolidation
# ...                                    ...                           ...
# 1937227                 Ultrasound Doppler                             0
# 1938416                                  0                             0
# 1938563                                  0                             0
# 1938760              Loss of consciousness            Respiratory arrest
# 1938760                                  0                             0
#
#                  VAX_MANU AGE_YRS SEX DIED L_THREAT ER_VISIT HOSPITAL DISABLE  \
# VAERS_ID
# 916710            MODERNA    23.0   F    N        Y        N        Y       N
# 916890    PFIZER\BIONTECH    39.0   F    N        Y        N        Y       N
# 916890    PFIZER\BIONTECH    39.0   F    N        Y        N        Y       N
# 917210    PFIZER\BIONTECH    30.0   F    N        Y        N        Y       N
# 917210    PFIZER\BIONTECH    30.0   F    N        Y        N        Y       N
# ...                   ...     ...  ..  ...      ...      ...      ...     ...
# 1937227   PFIZER\BIONTECH    42.0   M    N        Y        N        Y       N
# 1938416           MODERNA    69.0   F    N        Y        N        Y       N
# 1938563           MODERNA    55.0   M    N        Y        N        Y       N
# 1938760   PFIZER\BIONTECH     6.0   F    N        Y        N        Y       N
# 1938760   PFIZER\BIONTECH     6.0   F    N        Y        N        Y       N
#
#          BIRTH_DEFECT AGE_BIN
# VAERS_ID
# 916710              N   19-40
# 916890              N   19-40
# 916890              N   19-40
# 917210              N   19-40
# 917210              N   19-40
# ...               ...     ...
# 1937227             N   41-59
# 1938416             N     60+
# 1938563             N   41-59
# 1938760             N    0-18
# 1938760             N    0-18
#
# [18788 rows x 15 columns]

# %%
# take the remanin symptoms from all 5 rows and list out the top 100 symptoms
frames = [test['SYMPTOM1'], test['SYMPTOM2'], test['SYMPTOM3'], test['SYMPTOM4'], test['SYMPTOM5']]
result = pd.concat(frames)
R = result.value_counts()
symptomlist = R[R >= 200].index

# %%
symptomlist.value_counts()
# Out:
# Back pain                         1
# Computerised tomogram abnormal    1
# Echocardiogram                    1
# Electrocardiogram                 1
# Computerised tomogram             1
#                                  ..
# Laboratory test                   1
# Asthenia                          1
# Platelet count decreased          1
# Deep vein thrombosis              1
# COVID-19                          1
# Length: 75, dtype: int64

# %%
# narrow down the cleaned dataset against the top 200 symptoms
temp = ml_ready_df[ml_ready_df['SYMPTOM1'].isin(symptomlist)]
temp = temp[temp['SYMPTOM2'].isin(symptomlist)]
temp = temp[temp['SYMPTOM3'].isin(symptomlist)]
temp = temp[temp['SYMPTOM4'].isin(symptomlist)]
temp = temp[temp['SYMPTOM5'].isin(symptomlist)]
temp
# Out:
#                           SYMPTOM1           SYMPTOM2             SYMPTOM3  \
# VAERS_ID
# 916620                      Nausea  Pain in extremity              Pyrexia
# 916622                      Nausea                  0                    0
# 916631           Pain in extremity                  0                    0
# 916638               Hypoaesthesia  Pain in extremity  Peripheral swelling
# 916642                      Chills           Headache               Nausea
# ...                            ...                ...                  ...
# 1939024                  Dizziness      Hypoaesthesia                 Pain
# 1939035             Abdominal pain           Asthenia               Nausea
# 1939039           Chest discomfort         Chest pain                    0
# 1939081                   COVID-19             Chills                Cough
# 1939081   SARS-CoV-2 test positive                  0                    0
#
#                  SYMPTOM4           SYMPTOM5         VAX_MANU AGE_YRS SEX  \
# VAERS_ID
# 916620                  0                  0          MODERNA    65.0   M
# 916622                  0                  0          MODERNA    22.0   F
# 916631                  0                  0          MODERNA    25.0   F
# 916638    Ultrasound scan                  0  PFIZER\BIONTECH    41.0   M
# 916642               Pain  Pain in extremity          MODERNA    42.0   F
# ...                   ...                ...              ...     ...  ..
# 1939024                 0                  0          MODERNA    47.0   F
# 1939035              Pain           Vomiting          MODERNA    93.0   F
# 1939039                 0                  0  PFIZER\BIONTECH    20.0   M
# 1939081          Dyspnoea            Fatigue  PFIZER\BIONTECH    65.0   M
# 1939081                 0                  0  PFIZER\BIONTECH    65.0   M
#
#          DIED L_THREAT ER_VISIT HOSPITAL DISABLE BIRTH_DEFECT AGE_BIN
# VAERS_ID
# 916620      N        N        N        N       N            N     60+
# 916622      N        N        N        N       N            N   19-40
# 916631      N        N        N        N       N            N   19-40
# 916638      N        N        N        N       N            N   19-40
# 916642      N        N        N        N       N            N   41-59
# ...       ...      ...      ...      ...     ...          ...     ...
# 1939024     N        N        N        N       N            N   41-59
# 1939035     N        N        N        N       N            N     60+
# 1939039     N        N        N        N       N            N   19-40
# 1939081     N        N        N        N       N            N     60+
# 1939081     N        N        N        N       N            N     60+
#
# [135815 rows x 15 columns]

# %%
# # Export to CSV for Machine Learning
ml_ready_df.to_csv(r'MLdata.csv', index=True)
