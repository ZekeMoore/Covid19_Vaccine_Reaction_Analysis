# %% [raw]
# VAERS_Tableau_Exploratory_data

# %%
# import dependencies
import pandas as pd
import numpy as np

# %%
vax_csv = "clean_vaers_vax.csv"
symptoms_csv = "grouped_vaers_symptoms.csv"

# %%
vaers_vax = pd.read_csv(vax_csv, index_col=None, header=0, encoding='latin1', low_memory=False)
vaers_vax.head()
# Out:
#    VAERS_ID VAX_TYPE         VAX_MANU                             VAX_NAME
# 0    916600  COVID19          MODERNA          COVID19 (COVID19 (MODERNA))
# 1    916601  COVID19          MODERNA          COVID19 (COVID19 (MODERNA))
# 2    916602  COVID19  PFIZER\BIONTECH  COVID19 (COVID19 (PFIZER-BIONTECH))
# 3    916603  COVID19          MODERNA          COVID19 (COVID19 (MODERNA))
# 4    916604  COVID19          MODERNA          COVID19 (COVID19 (MODERNA))

# %%
# reading vaers symptoms as dataframe
vaers_symptoms = pd.read_csv(symptoms_csv, index_col=None, header=0, encoding='latin1', low_memory=False)
vaers_symptoms.head()
# Out:
#    VAERS_ID                 SYMPTOM1                 SYMPTOM2  \
# 0    916600                Dysphagia             Epiglottitis
# 1    916601                  Anxiety                 Dyspnoea
# 2    916602         Chest discomfort                Dysphagia
# 3    916603                Dizziness                  Fatigue
# 4    916604  Injection site erythema  Injection site pruritus
#
#                   SYMPTOM3               SYMPTOM4 SYMPTOM5
# 0                      NaN                    NaN      NaN
# 1                      NaN                    NaN      NaN
# 2        Pain in extremity      Visual impairment      NaN
# 3       Mobility decreased                    NaN      NaN
# 4  Injection site swelling  Injection site warmth      NaN

# %%
# using merge function by setting how='inner'
vaxsymp = pd.merge(vaers_vax, vaers_symptoms, 
                   on='VAERS_ID', 
                   how='inner')
vaxsymp.head()
# Out:
#    VAERS_ID VAX_TYPE         VAX_MANU                             VAX_NAME  \
# 0    916600  COVID19          MODERNA          COVID19 (COVID19 (MODERNA))
# 1    916601  COVID19          MODERNA          COVID19 (COVID19 (MODERNA))
# 2    916602  COVID19  PFIZER\BIONTECH  COVID19 (COVID19 (PFIZER-BIONTECH))
# 3    916603  COVID19          MODERNA          COVID19 (COVID19 (MODERNA))
# 4    916604  COVID19          MODERNA          COVID19 (COVID19 (MODERNA))
#
#                   SYMPTOM1                 SYMPTOM2                 SYMPTOM3  \
# 0                Dysphagia             Epiglottitis                      NaN
# 1                  Anxiety                 Dyspnoea                      NaN
# 2         Chest discomfort                Dysphagia        Pain in extremity
# 3                Dizziness                  Fatigue       Mobility decreased
# 4  Injection site erythema  Injection site pruritus  Injection site swelling
#
#                 SYMPTOM4 SYMPTOM5
# 0                    NaN      NaN
# 1                    NaN      NaN
# 2      Visual impairment      NaN
# 3                    NaN      NaN
# 4  Injection site warmth      NaN

# %%
# check column list
list(vaxsymp.columns)
# Out:
# ['VAERS_ID',
#  'VAX_TYPE',
#  'VAX_MANU',
#  'VAX_NAME',
#  'SYMPTOM1',
#  'SYMPTOM2',
#  'SYMPTOM3',
#  'SYMPTOM4',
#  'SYMPTOM5']

# %%
# after you run this once, it will error if you try it again because well.. its deleted.
# del vaxsymp['Unnamed: 0']

# %%
# check DF
vaxsymp
# Out:
#         VAERS_ID VAX_TYPE              VAX_MANU  \
# 0         916600  COVID19               MODERNA
# 1         916601  COVID19               MODERNA
# 2         916602  COVID19       PFIZER\BIONTECH
# 3         916603  COVID19               MODERNA
# 4         916604  COVID19               MODERNA
# ...          ...      ...                   ...
# 762754   1939089     FLU4        SANOFI PASTEUR
# 762755   1939102  COVID19       PFIZER\BIONTECH
# 762756   1939113  COVID19       PFIZER\BIONTECH
# 762757   1939114      UNK  UNKNOWN MANUFACTURER
# 762758   1939125      UNK  UNKNOWN MANUFACTURER
#
#                                            VAX_NAME  \
# 0                       COVID19 (COVID19 (MODERNA))
# 1                       COVID19 (COVID19 (MODERNA))
# 2               COVID19 (COVID19 (PFIZER-BIONTECH))
# 3                       COVID19 (COVID19 (MODERNA))
# 4                       COVID19 (COVID19 (MODERNA))
# ...                                             ...
# 762754  INFLUENZA (SEASONAL) (FLUZONE QUADRIVALENT)
# 762755          COVID19 (COVID19 (PFIZER-BIONTECH))
# 762756          COVID19 (COVID19 (PFIZER-BIONTECH))
# 762757                VACCINE NOT SPECIFIED (OTHER)
# 762758                VACCINE NOT SPECIFIED (OTHER)
#
#                                    SYMPTOM1                      SYMPTOM2  \
# 0                                 Dysphagia                  Epiglottitis
# 1                                   Anxiety                      Dyspnoea
# 2                          Chest discomfort                     Dysphagia
# 3                                 Dizziness                       Fatigue
# 4                   Injection site erythema       Injection site pruritus
# ...                                     ...                           ...
# 762754                           Arthralgia           Injection site pain
# 762755                      Lymph node pain               Lymphadenopathy
# 762756                        Adverse event                           NaN
# 762757            Chest pain, Muscle spasms                  Chills, Pain
# 762758  Ageusia, Magnetic resonance imaging  Blood test, Weight decreased
#
#                           SYMPTOM3                 SYMPTOM4  \
# 0                              NaN                      NaN
# 1                              NaN                      NaN
# 2                Pain in extremity        Visual impairment
# 3               Mobility decreased                      NaN
# 4          Injection site swelling    Injection site warmth
# ...                            ...                      ...
# 762754           Pain in extremity                      NaN
# 762755                      Nodule                      NaN
# 762756                         NaN                      NaN
# 762757              Cough, Pyrexia            Headache, nan
# 762758  Computerised tomogram, nan  Decreased appetite, nan
#
#                         SYMPTOM5
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# ...                          ...
# 762754                       NaN
# 762755                       NaN
# 762756                       NaN
# 762757  Injection site rash, nan
# 762758           Hypophagia, nan
#
# [762759 rows x 9 columns]

# %%
covid_df = vaxsymp[vaxsymp["VAX_TYPE"] == 'COVID19']
covid_df
# Out:
#         VAERS_ID VAX_TYPE         VAX_MANU  \
# 0         916600  COVID19          MODERNA
# 1         916601  COVID19          MODERNA
# 2         916602  COVID19  PFIZER\BIONTECH
# 3         916603  COVID19          MODERNA
# 4         916604  COVID19          MODERNA
# ...          ...      ...              ...
# 762750   1939062  COVID19  PFIZER\BIONTECH
# 762751   1939063  COVID19  PFIZER\BIONTECH
# 762753   1939081  COVID19  PFIZER\BIONTECH
# 762755   1939102  COVID19  PFIZER\BIONTECH
# 762756   1939113  COVID19  PFIZER\BIONTECH
#
#                                    VAX_NAME  \
# 0               COVID19 (COVID19 (MODERNA))
# 1               COVID19 (COVID19 (MODERNA))
# 2       COVID19 (COVID19 (PFIZER-BIONTECH))
# 3               COVID19 (COVID19 (MODERNA))
# 4               COVID19 (COVID19 (MODERNA))
# ...                                     ...
# 762750  COVID19 (COVID19 (PFIZER-BIONTECH))
# 762751  COVID19 (COVID19 (PFIZER-BIONTECH))
# 762753  COVID19 (COVID19 (PFIZER-BIONTECH))
# 762755  COVID19 (COVID19 (PFIZER-BIONTECH))
# 762756  COVID19 (COVID19 (PFIZER-BIONTECH))
#
#                                             SYMPTOM1                 SYMPTOM2  \
# 0                                          Dysphagia             Epiglottitis
# 1                                            Anxiety                 Dyspnoea
# 2                                   Chest discomfort                Dysphagia
# 3                                          Dizziness                  Fatigue
# 4                            Injection site erythema  Injection site pruritus
# ...                                              ...                      ...
# 762750                     Product preparation issue                      NaN
# 762751                                      Swelling            Swelling face
# 762753  COVID-19, Headache, SARS-CoV-2 test positive     Chills, Myalgia, nan
# 762755                               Lymph node pain          Lymphadenopathy
# 762756                                 Adverse event                      NaN
#
#                               SYMPTOM3                SYMPTOM4  \
# 0                                  NaN                     NaN
# 1                                  NaN                     NaN
# 2                    Pain in extremity       Visual impairment
# 3                   Mobility decreased                     NaN
# 4              Injection site swelling   Injection site warmth
# ...                                ...                     ...
# 762750                             NaN                     NaN
# 762751                             NaN                     NaN
# 762753  Cough, Oropharyngeal pain, nan  Dyspnoea, Pyrexia, nan
# 762755                          Nodule                     NaN
# 762756                             NaN                     NaN
#
#                          SYMPTOM5
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# ...                           ...
# 762750                        NaN
# 762751                        NaN
# 762753  Fatigue, Rhinorrhoea, nan
# 762755                        NaN
# 762756                        NaN
#
# [710158 rows x 9 columns]

# %%
# check to make sure only covid vaccines are in the list
covid_list = covid_df['VAX_MANU'].unique()
covid_list
# Out:
# array(['MODERNA', 'PFIZER\\BIONTECH', 'UNKNOWN MANUFACTURER', 'JANSSEN'],
#       dtype=object)

# %%
# save to csv
covid_df.to_csv(r'VAERSvaxsymptoms.csv', index=True)

# %%
file_to_load = "VAERSvaxsymptoms.csv"

# Read the CSV into a DataFrame
vaers_master_df = pd.read_csv(file_to_load)
vaers_master_df
# Out:
#         Unnamed: 0  VAERS_ID VAX_TYPE         VAX_MANU  \
# 0                0    916600  COVID19          MODERNA
# 1                1    916601  COVID19          MODERNA
# 2                2    916602  COVID19  PFIZER\BIONTECH
# 3                3    916603  COVID19          MODERNA
# 4                4    916604  COVID19          MODERNA
# ...            ...       ...      ...              ...
# 710153      762750   1939062  COVID19  PFIZER\BIONTECH
# 710154      762751   1939063  COVID19  PFIZER\BIONTECH
# 710155      762753   1939081  COVID19  PFIZER\BIONTECH
# 710156      762755   1939102  COVID19  PFIZER\BIONTECH
# 710157      762756   1939113  COVID19  PFIZER\BIONTECH
#
#                                    VAX_NAME  \
# 0               COVID19 (COVID19 (MODERNA))
# 1               COVID19 (COVID19 (MODERNA))
# 2       COVID19 (COVID19 (PFIZER-BIONTECH))
# 3               COVID19 (COVID19 (MODERNA))
# 4               COVID19 (COVID19 (MODERNA))
# ...                                     ...
# 710153  COVID19 (COVID19 (PFIZER-BIONTECH))
# 710154  COVID19 (COVID19 (PFIZER-BIONTECH))
# 710155  COVID19 (COVID19 (PFIZER-BIONTECH))
# 710156  COVID19 (COVID19 (PFIZER-BIONTECH))
# 710157  COVID19 (COVID19 (PFIZER-BIONTECH))
#
#                                             SYMPTOM1                 SYMPTOM2  \
# 0                                          Dysphagia             Epiglottitis
# 1                                            Anxiety                 Dyspnoea
# 2                                   Chest discomfort                Dysphagia
# 3                                          Dizziness                  Fatigue
# 4                            Injection site erythema  Injection site pruritus
# ...                                              ...                      ...
# 710153                     Product preparation issue                      NaN
# 710154                                      Swelling            Swelling face
# 710155  COVID-19, Headache, SARS-CoV-2 test positive     Chills, Myalgia, nan
# 710156                               Lymph node pain          Lymphadenopathy
# 710157                                 Adverse event                      NaN
#
#                               SYMPTOM3                SYMPTOM4  \
# 0                                  NaN                     NaN
# 1                                  NaN                     NaN
# 2                    Pain in extremity       Visual impairment
# 3                   Mobility decreased                     NaN
# 4              Injection site swelling   Injection site warmth
# ...                                ...                     ...
# 710153                             NaN                     NaN
# 710154                             NaN                     NaN
# 710155  Cough, Oropharyngeal pain, nan  Dyspnoea, Pyrexia, nan
# 710156                          Nodule                     NaN
# 710157                             NaN                     NaN
#
#                          SYMPTOM5
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# ...                           ...
# 710153                        NaN
# 710154                        NaN
# 710155  Fatigue, Rhinorrhoea, nan
# 710156                        NaN
# 710157                        NaN
#
# [710158 rows x 10 columns]

# %%
vaers_master_df.describe()
# Out:
#           Unnamed: 0      VAERS_ID
# count  710158.000000  7.101580e+05
# mean   377786.745724  1.383518e+06
# std    218715.217281  2.940972e+05
# min         0.000000  9.166000e+05
# 25%    189438.250000  1.131680e+06
# 50%    375898.500000  1.346490e+06
# 75%    564772.750000  1.631360e+06
# max    762756.000000  1.939113e+06

# %%
#Print Coulumns
print(vaers_master_df.columns)
# Out:
# Index(['Unnamed: 0', 'VAERS_ID', 'VAX_TYPE', 'VAX_MANU', 'VAX_NAME',
#        'SYMPTOM1', 'SYMPTOM2', 'SYMPTOM3', 'SYMPTOM4', 'SYMPTOM5'],
#       dtype='object')

# %%
len(vaers_master_df)
# Out:
# 710158

# %%
#Sorted
sorted(vaers_master_df.columns.tolist())
# Out:
# ['SYMPTOM1',
#  'SYMPTOM2',
#  'SYMPTOM3',
#  'SYMPTOM4',
#  'SYMPTOM5',
#  'Unnamed: 0',
#  'VAERS_ID',
#  'VAX_MANU',
#  'VAX_NAME',
#  'VAX_TYPE']

# %%
vaers_master_df.dtypes
# Out:
# Unnamed: 0     int64
# VAERS_ID       int64
# VAX_TYPE      object
# VAX_MANU      object
# VAX_NAME      object
# SYMPTOM1      object
# SYMPTOM2      object
# SYMPTOM3      object
# SYMPTOM4      object
# SYMPTOM5      object
# dtype: object

# %%
vaers_master_df.tail()
# Out:
#         Unnamed: 0  VAERS_ID VAX_TYPE         VAX_MANU  \
# 710153      762750   1939062  COVID19  PFIZER\BIONTECH
# 710154      762751   1939063  COVID19  PFIZER\BIONTECH
# 710155      762753   1939081  COVID19  PFIZER\BIONTECH
# 710156      762755   1939102  COVID19  PFIZER\BIONTECH
# 710157      762756   1939113  COVID19  PFIZER\BIONTECH
#
#                                    VAX_NAME  \
# 710153  COVID19 (COVID19 (PFIZER-BIONTECH))
# 710154  COVID19 (COVID19 (PFIZER-BIONTECH))
# 710155  COVID19 (COVID19 (PFIZER-BIONTECH))
# 710156  COVID19 (COVID19 (PFIZER-BIONTECH))
# 710157  COVID19 (COVID19 (PFIZER-BIONTECH))
#
#                                             SYMPTOM1              SYMPTOM2  \
# 710153                     Product preparation issue                   NaN
# 710154                                      Swelling         Swelling face
# 710155  COVID-19, Headache, SARS-CoV-2 test positive  Chills, Myalgia, nan
# 710156                               Lymph node pain       Lymphadenopathy
# 710157                                 Adverse event                   NaN
#
#                               SYMPTOM3                SYMPTOM4  \
# 710153                             NaN                     NaN
# 710154                             NaN                     NaN
# 710155  Cough, Oropharyngeal pain, nan  Dyspnoea, Pyrexia, nan
# 710156                          Nodule                     NaN
# 710157                             NaN                     NaN
#
#                          SYMPTOM5
# 710153                        NaN
# 710154                        NaN
# 710155  Fatigue, Rhinorrhoea, nan
# 710156                        NaN
# 710157                        NaN

# %%
vaers_master_df.sample()
# Out:
#         Unnamed: 0  VAERS_ID VAX_TYPE VAX_MANU                     VAX_NAME  \
# 125780      134397   1068482  COVID19  MODERNA  COVID19 (COVID19 (MODERNA))
#
#                                                  SYMPTOM1 SYMPTOM2 SYMPTOM3  \
# 125780  Product administered to patient of inappropria...      NaN      NaN
#
#        SYMPTOM4 SYMPTOM5
# 125780      NaN      NaN

# %%
vaers_master_df.columns.tolist()
# Out:
# ['Unnamed: 0',
#  'VAERS_ID',
#  'VAX_TYPE',
#  'VAX_MANU',
#  'VAX_NAME',
#  'SYMPTOM1',
#  'SYMPTOM2',
#  'SYMPTOM3',
#  'SYMPTOM4',
#  'SYMPTOM5']

# %%
vaers_master_df.value_counts()
# Out:
# Unnamed: 0  VAERS_ID  VAX_TYPE  VAX_MANU         VAX_NAME                             SYMPTOM1                                                                                    SYMPTOM2                                                                   SYMPTOM3                                                        SYMPTOM4                                                                         SYMPTOM5
# 11          916611    COVID19   MODERNA          COVID19 (COVID19 (MODERNA))          Blood pressure decreased, Dyspnoea, Heart rate decreased, Nausea, SARS-CoV-2 antibody test  Chest pain, Fatigue, Heart rate increased, Pain, SARS-CoV-2 test negative  Chills, Feeling abnormal, Hypertension, Pain in extremity, nan  Confusional state, Head discomfort, Injection site pain, Paraesthesia oral, nan  Decreased appetite, Headache, Musculoskeletal chest pain, Pyrexia, nan    1
# 488395      1535212   COVID19   MODERNA          COVID19 (COVID19 (MODERNA))          Blindness, Magnetic resonance imaging                                                       Blood test, Ophthalmological examination                                   Computerised tomogram, Syncope                                  Dizziness, nan                                                                   Headache, nan                                                             1
# 488329      1535150   COVID19   MODERNA          COVID19 (COVID19 (MODERNA))          Hypoaesthesia, Thermal burn                                                                 Mobility decreased, nan                                                    Muscular weakness, nan                                          Pain, nan                                                                        Paraesthesia, nan                                                         1
# 488330      1535151   COVID19   MODERNA          COVID19 (COVID19 (MODERNA))          Acoustic stimulation tests, Dizziness, Migraine, Vision blurred                             Asthenopia, Fatigue, Mood swings, nan                                      Balance disorder, Headache, Syncope, nan                        Blood test, Magnetic resonance imaging, Tilt table test, nan                     Computerised tomogram, Magnetic resonance imaging spinal, Vertigo, nan    1
# 488335      1535155   COVID19   PFIZER\BIONTECH  COVID19 (COVID19 (PFIZER-BIONTECH))  Blood glucose increased                                                                     Chills                                                                     Confusional state                                               Pain in extremity                                                                Pyrexia                                                                   1
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ..
# 239714      1188350   COVID19   MODERNA          COVID19 (COVID19 (MODERNA))          Headache                                                                                    Injection site pain                                                        Injection site reaction                                         Nasal congestion                                                                 Sneezing                                                                  1
# 239716      1188352   COVID19   MODERNA          COVID19 (COVID19 (MODERNA))          Blood test, Heart rate increased                                                            Chest pain, Injection site lymphadenopathy                                 Computerised tomogram, nan                                      Dyspnoea, nan                                                                    Gastrooesophageal reflux disease, nan                                     1
# 239718      1188354   COVID19   JANSSEN          COVID19 (COVID19 (JANSSEN))          Body temperature increased, Injection site pain                                             Chills, Myalgia                                                            Disturbance in attention, Skin burning sensation                Fatigue, nan                                                                     Feeling hot, nan                                                          1
# 239722      1188358   COVID19   MODERNA          COVID19 (COVID19 (MODERNA))          Abdominal discomfort, Headache                                                              Arthralgia, Joint swelling                                                 Eye pain, Respiratory tract congestion                          Eye swelling, SARS-CoV-2 test negative                                           Fatigue, Tinnitus                                                         1
# 762753      1939081   COVID19   PFIZER\BIONTECH  COVID19 (COVID19 (PFIZER-BIONTECH))  COVID-19, Headache, SARS-CoV-2 test positive                                                Chills, Myalgia, nan                                                       Cough, Oropharyngeal pain, nan                                  Dyspnoea, Pyrexia, nan                                                           Fatigue, Rhinorrhoea, nan                                                 1
# Length: 249608, dtype: int64

# %%
#Print Coulumns
print(vaers_master_df.columns)
# Out:
# Index(['Unnamed: 0', 'VAERS_ID', 'VAX_TYPE', 'VAX_MANU', 'VAX_NAME',
#        'SYMPTOM1', 'SYMPTOM2', 'SYMPTOM3', 'SYMPTOM4', 'SYMPTOM5'],
#       dtype='object')

# %%
vaers_master_df.index
# Out:
# RangeIndex(start=0, stop=710158, step=1)

# %%
vaers_master_df.values
# Out:
# array([[0, 916600, 'COVID19', ..., nan, nan, nan],
#        [1, 916601, 'COVID19', ..., nan, nan, nan],
#        [2, 916602, 'COVID19', ..., 'Pain in extremity',
#         'Visual impairment', nan],
#        ...,
#        [762753, 1939081, 'COVID19', ...,
#         'Cough, Oropharyngeal pain, nan', 'Dyspnoea, Pyrexia, nan',
#         'Fatigue, Rhinorrhoea, nan'],
#        [762755, 1939102, 'COVID19', ..., 'Nodule', nan, nan],
#        [762756, 1939113, 'COVID19', ..., nan, nan, nan]], dtype=object)

# %%
#lens 
len(vaers_master_df)
# Out:
# 710158

# %%
vaers_master_df.isnull()
# Out:
#         Unnamed: 0  VAERS_ID  VAX_TYPE  VAX_MANU  VAX_NAME  SYMPTOM1  \
# 0            False     False     False     False     False     False
# 1            False     False     False     False     False     False
# 2            False     False     False     False     False     False
# 3            False     False     False     False     False     False
# 4            False     False     False     False     False     False
# ...            ...       ...       ...       ...       ...       ...
# 710153       False     False     False     False     False     False
# 710154       False     False     False     False     False     False
# 710155       False     False     False     False     False     False
# 710156       False     False     False     False     False     False
# 710157       False     False     False     False     False     False
#
#         SYMPTOM2  SYMPTOM3  SYMPTOM4  SYMPTOM5
# 0          False      True      True      True
# 1          False      True      True      True
# 2          False     False     False      True
# 3          False     False      True      True
# 4          False     False     False      True
# ...          ...       ...       ...       ...
# 710153      True      True      True      True
# 710154     False      True      True      True
# 710155     False     False     False     False
# 710156     False     False      True      True
# 710157      True      True      True      True
#
# [710158 rows x 10 columns]

# %%
vaers_master_df.head()
# Out:
#    Unnamed: 0  VAERS_ID VAX_TYPE         VAX_MANU  \
# 0           0    916600  COVID19          MODERNA
# 1           1    916601  COVID19          MODERNA
# 2           2    916602  COVID19  PFIZER\BIONTECH
# 3           3    916603  COVID19          MODERNA
# 4           4    916604  COVID19          MODERNA
#
#                               VAX_NAME                 SYMPTOM1  \
# 0          COVID19 (COVID19 (MODERNA))                Dysphagia
# 1          COVID19 (COVID19 (MODERNA))                  Anxiety
# 2  COVID19 (COVID19 (PFIZER-BIONTECH))         Chest discomfort
# 3          COVID19 (COVID19 (MODERNA))                Dizziness
# 4          COVID19 (COVID19 (MODERNA))  Injection site erythema
#
#                   SYMPTOM2                 SYMPTOM3               SYMPTOM4  \
# 0             Epiglottitis                      NaN                    NaN
# 1                 Dyspnoea                      NaN                    NaN
# 2                Dysphagia        Pain in extremity      Visual impairment
# 3                  Fatigue       Mobility decreased                    NaN
# 4  Injection site pruritus  Injection site swelling  Injection site warmth
#
#   SYMPTOM5
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN

# %%
# End of the Tableau Exploratory Data
